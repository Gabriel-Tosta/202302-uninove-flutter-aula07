# %% [markdown]
# <a href="https://colab.research.google.com/github/Gabriel-Tosta/202302-uninove-flutter-aula07/blob/main/Mtcars_panda_numpy_VG_2025.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Neste estudo iremos trabalhar com o dataset MTcars.csv
# Não esqueça de copiar- Upload o dataset para o Colab, pasta ao lado.
# Também não esqueça de carregar a biblioteca pandas
# <br>
# e carregar o arquivo "Mtcars.csv". voce pode usar o print(), matcars.head() e Mtcars.<br>
# Características:<br>
# mpg: Milhas por Galão (consumo)<br>
# cyl: Número de cilíndros<br>
# disp: Cilindada (em polegada cúbica)<br>
# hp: Cavalos de Potência (HP)<br>
# drat: Relação do eixo traseiro<br>
# wt: Peso em (1,000 libras)<br>
# qsec: Tempo que atinge 400m (1/4 de milha)<br>
# vs: Motor (0 = Forma em V, 1 = Reto)<br>
# am: Transmissão (0 = Automático, 1 = Manual)<br>
# gear: Número de marchas<br>
# carb: Número de carburadores<br>

# %%
# import as bibliotecas e o arquivo MTcars.csv
import pandas as pd
mtcars=pd.read_csv("/content/mtcars.csv") # trocar endereço

# %% [markdown]
# MOnte uma tabela dos carros mais gastões de combustivel para os menos gastões

# %%
df.sort_values('mpg').head()

# %% [markdown]
# Podemos afirmar que os carros de maior cilindrada são os de maior consumo

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.scatterplot(data=df, x='disp', y='mpg')
plt.title('Cilindrada vs. Consumo (mpg)')
plt.xlabel('Cilindrada (disp)')
plt.ylabel('Consumo (mpg)')
plt.show()

# %% [markdown]
# Os carros mais rápidos são motores em V ou em linha

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.boxplot(data=df, x='vs', y='qsec')
plt.title('Tempo de 1/4 milha por tipo de motor')
plt.xlabel('Tipo de Motor (0 = V, 1 = Linha)')
plt.ylabel('Tempo (qsec)')
plt.show()

# %% [markdown]
# O peso esta relacionado com o numero de cilindro

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# carregando o dataset
mtcars = pd.read_csv('/mnt/data/mtcars.csv')

# gráfico
plt.figure(figsize=(8,5))
sns.scatterplot(data=mtcars, x='cyl', y='wt', hue='cyl', palette='viridis', s=100)
plt.title('Peso x Número de Cilindros')
plt.xlabel('Número de cilindros')
plt.ylabel('Peso (1000 libras)')
plt.show()

# %% [markdown]
# Existe uma relação entre o numero de marchas em relação ao numero de carburadores

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

mtcars = pd.read_csv('/mnt/data/mtcars.csv')


tabela = pd.crosstab(mtcars['gear'], mtcars['carb'])
print(tabela)

# %% [markdown]
# Mostre os 3 carros de maior consumo e os 3 de menor consumo

# %%
import pandas as pd

# Carregar arquivo (supondo que você fez upload no Colab)
mtcars = pd.read_csv("mtcars.csv")

# 3 carros de MAIOR consumo (menor mpg)
maior_consumo = mtcars.sort_values(by="mpg", ascending=True).head(3)
print("3 carros de MAIOR consumo (menor mpg):")
print(maior_consumo)

# %%
import pandas as pd

# Carregar arquivo (supondo que você fez upload no Colab)
mtcars = pd.read_csv("mtcars.csv")



# 3 carros de MENOR consumo (maior mpg)
menor_consumo = mtcars.sort_values(by="mpg", ascending=False).head(3)
print("\n3 carros de MENOR consumo (maior mpg):")
print(menor_consumo)

# %% [markdown]
# Calcule a media de consumo e media de cilindradas deste dataset

# %%
# média de consumo (mpg)
media_consumo = mtcars["mpg"].mean()
media_consumo

# %%
# média de cilindrada (disp)
media_cilindrada = mtcars["disp"].mean()
media_cilindrada
